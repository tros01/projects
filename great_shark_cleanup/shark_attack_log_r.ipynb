# %% [markdown]
# # Shark attack log

# %%
# Libraries
library(tidyverse)
library(readxl)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# Helpers
quiet <- function(x) {
    # Suppress both messages and warnings
    suppressMessages(suppressWarnings(x))
}

clean_str <- function(s) {
    # Convert to lower case and trim whitespaces
    return(str_to_lower(str_squish(s)))
}

# %%
# Data
file_url <- r"(https://www.sharkattackfile.net/spreadsheets/GSAF5.xls)"

    # Load up the spreadsheet into a temporary file 
temp_file <- tempfile(fileext = ".xls")
download.file(file_url, temp_file, mode = "wb")

# %%
df <- quiet(
        read_excel(
            temp_file,
            col_names = TRUE, 
            col_types = NULL
        )
    )
# df |> head(n=10)

# %%
# df structure
df |> str()
# Out:
# tibble [7,058 × 23] (S3: tbl_df/tbl/data.frame)
#  $ Date            : chr [1:7058] "27th November" "27th November" "10th November" "9th November" ...
#  $ Year            : chr [1:7058] "2025" "2025" "2025" "2025" ...
#  $ Type            : chr [1:7058] "Unprovoked" "Unprovoked" "Unprovoked" "Unprovoked" ...
#  $ Country         : chr [1:7058] "Australia" "Australia" "Australia" "French Polynesia" ...
#  $ State           : chr [1:7058] "NSW" "NSW" "Western Australia" "Marquesas Islands" ...
#  $ Location        : chr [1:7058] "Crowdy Bay" "Crowdy Bay" "Prevelly Beach Magaret River" "Hakahau Bay" ...
#  $ Activity        : chr [1:7058] "Swimming" "Swimming" "Foil Boarding" "Swimming" ...
#  $ Name            : chr [1:7058] "Lukas Schindler" "Livia Mulheim" "Andy McDonald" "Not stated (Dentist)" ...
#  $ Sex             : chr [1:7058] "M" "F" "M" "M" ...
#  $ Age             : chr [1:7058] "26" "25" "61" "40" ...
#  $ Injury          : chr [1:7058] "Serious leg injuries" "Not stated" "No Injury to self" "Deep Gash to bicep" ...
#  $ Fatal Y/N       : chr [1:7058] "N" "Y" "N" "N" ...
#  $ Time            : chr [1:7058] "0630hrs" "0630hrs" "1745hrs" "Not stated" ...
#  $ Species         : chr [1:7058] "3m Bull shark" "3m Bull shark" "Great White Shark" "3m shark" ...
#  $ Source          : chr [1:7058] "Media: Todd Smith: Andy Currie: Simon De Marchi: Kevin McMurray Tracking sharks.com" "Media: Todd Smith: Andy Currie: Simon De Marchi: Kevin McMurray Tracking sharks.com" "Andy Currie" "Andrew Currie" ...
#  $ pdf             : chr [1:7058] NA NA NA NA ...
#  $ href formula    : chr [1:7058] NA NA NA NA ...
#  $ href            : chr [1:7058] NA NA NA NA ...
#  $ Case Number...19: chr [1:7058] NA NA NA NA ...
#  $ Case Number...20: chr [1:7058] NA NA NA NA ...
#  $ original order  : num [1:7058] NA NA NA NA NA NA NA NA NA NA ...
#  $ ...22           : logi [1:7058] NA NA NA NA NA NA ...
#  $ ...23           : logi [1:7058] NA NA NA NA NA NA ...

# %%
# df dimensions
df |> dim()
# Out:
# [1] 7058   23

# %% [markdown]
# ## Clean up

# %%
# Clean up the data frame
df <- df |>
    janitor::clean_names() |>
    mutate(
        # Year as integer
        year = as.integer(year),
        # Type of attack as factor
        type = factor(
            clean_str(type), 
            levels = c("unprovoked", "provoked", "questionable", "watercraft")
        ),
        # Age as integer
        age = as.integer(age),
        # Sex as factor
        sex = factor(
            clean_str(sex), 
            levels = c("m", "f")
        ),
        # Binary fatality status
        fatal = factor(
                case_match(
                    fatal_y_n,
                    "Y" ~ 1,
                    "N" ~ 0,
                    .default = NA_integer_
                ),
            levels = c(0, 1)
        )
    ) |>
    mutate(
        across(
            # Convert to lower case and purge whitespaces
            .cols = c("date", "time", "activity", "injury", "species"),
            .fns = ~ str_to_lower(str_squish(.x))
        )
    ) |>
    mutate(
        across(
            # Purge whitespaces
            .cols = c("country", "state", "location", "name"),
            .fns = ~ str_squish(.x)
        )
    ) |>
    select(-fatal_y_n)
# Out:
# Warning message:
# "There was 1 warning in `mutate()`.
# ℹ In argument: `age = as.integer(age)`.
# Caused by warning:
# ! NAs introduced by coercion"

# %% [markdown]
# ###  Clean the time column
#
# - recode `time` as time
# - construct a `time_of_day` column

# %%
# Extract the raw column
raw_time <- df$time

# Clean up the values
hrs_mins <- str_match(raw_time, "(\\d{1,2})[a-z]*?(\\d{2})")
clean_time <- ifelse(!is.na(hrs_mins)[,1], paste(hrs_mins[,2], ":", hrs_mins[,3]), NA)

# Override the original column with clean time values
df["time"] <- hm(clean_time)

# Classify phases of day
day_phases <- r"(daybreak: 04:00–06:59
morning: 07:00–11:59
afternoon: 12:00–16:59
nightfall: 17:00–20:59
night: 21:00–03:59)"

# Match the string components
day_phases_components <- str_match_all(day_phases, "(\\w+):\\s*(\\d{2}:\\d{2})[–-](\\d{2}:\\d{2})")[[1]]

# Construct a key
day_phases_key <- tibble(
    phase = day_phases_components[,2],
    start = hm(day_phases_components[,3]),
    end = hm(day_phases_components[,4])
)

# %%
# Recode day phases
day_phases <- sapply(
    seq(nrow(df)),
    \(i) {
        t <- df$time[i]   # Or df[["time"]][i]
        raw_t <- raw_time[[i]]
        raw_s <- str_extract(raw_t, "[a-z ]+")

        if (!is.na(t)) {
            s_mask <- day_phases_key$start >= t
            e_mask <- day_phases_key$end <= t
            idx <- which(s_mask & e_mask)
            
            if (length(idx) == 1L) {
                phase <- day_phases_key[idx, "phase"]
                return(phase)
            } else {
                return("night")
            }
        } else if (!is.na(raw_s)) {
            a_match <- setdiff(
                unlist(str_split(raw_s, " ")),
                day_phases_key$phase
            )
            if (length(a_match) > 0) {
                return(raw_s)
            } else {
                return(NA_character_)
            }
        } else {
            return(NA_character_)
        }
    }
)

df <- df |>
    relocate(
        time,
        .after = "year"
    ) |>
    mutate(
        time_of_day = factor(day_phases, levels = unique(unlist(day_phases)))
    ) |>
    relocate(
        time_of_day,
        .after = "time"
    )

# %% [markdown]
# ### Clean the date column
#
# - recode `date` as date
# - construct `date_notes` column

# %%
# Construct date_notes
df <- df |>
    mutate(
        date_notes = date
    )

# %%
# Construct a helper
clean_historical_date <- function(date_str, year_col = NA_integer_) {
      d <- date_str |>
        # Take reported for actual
        str_remove("^reported\\s+") |>
        # Remove suffixes
        str_replace_all("(?<=\\d)(st|nd|rd|th)", "")
  
    # Extract the year from the separate column
    year_present <- str_detect(d, "\\b\\d{4}\\b")
  
    d <- ifelse(
        !year_present & !is.na(year_col),
        paste(d, year_col),
        d
    )
  
    # Let lubridate parse the muddle
    parse_date_time(
        d,
        orders = c("d B Y", "B Y", "d-b-Y", "b-d-Y", "d B"),
        quiet = TRUE
    ) |> as.Date()
}

# Clean the column
df <- df |>
    mutate(
        date = clean_historical_date(date, year)
    )

# %% [markdown]
# ## Clean species
#
# - normalise `species` column
# - construct `specimen_size` column

# %%
# Construct size columns
df <- df |>
    mutate(
        size_m = str_extract(species, "\\d*\\.?\\d+(?=m)"),
        size_ft = str_extract(species, "\\d*\\.?\\d+(?=ft)")
    )

# %%
# Clean the species column
df <- df |>
    mutate(
        species = str_replace_all(
            species,
            c("wfite" = "white",
              "shart" = "shark",
              "broze" = "bronze",
              "carribean" = "caribbean",
              "galapogas" = "galapagos",
              "shall" = "small")
        ),
        species =  case_when(
                str_detect(species, "oceanic whitetip") ~ "oceanic whitetip shark",
                str_detect(species, "blacktip reef") ~ "blacktip reef shark",
                str_detect(species, "caribbean reef") ~ "caribbean reef shark",
                str_detect(species, "sand tiger|raggedtooth")~ "sand tiger shark",
                str_detect(species, "sandbar") ~ "sandbar shark",
                str_detect(species, "bronze whaler") ~ "bronze whaler",
                str_detect(species, "wobbegong") ~ "wobbegong shark",
                str_detect(species, "sevengill") ~ "sevengill shark",
                str_detect(species, "cookiecutter") ~ "cookiecutter shark",
                str_detect(species, "reef shark") ~ "reef shark",
                 
                str_detect(species, "lemon") ~ "lemon shark",
                str_detect(species, "nurse") ~ "nurse shark",
                str_detect(species, "blacktip") ~ "blacktip shark",
                str_detect(species, "mako") ~ "mako shark",
                str_detect(species, "blue") ~ "blue shark",
                str_detect(species, "dusky") ~ "dusky shark",
                str_detect(species, "galapagos") ~ "galapagos shark",
                str_detect(species, "reef") ~ "reef shark",
                 
                str_detect(species, "bull") ~ "bull shark",
                str_detect(species, "tiger") ~ "tiger shark",
                str_detect(species, "great white|white shark|white shark") ~ "white shark",
                TRUE ~ NA_character_
            )


    )

# %% [markdown]
# ## Final touches
#
# - select cols
# - filter out NA years

# %%
clean_df <- df |>
    select(date, year, time, time_of_day, type, country, state, location, activity, name, sex, injury, fatal, species, size_m, size_ft) |>
    filter(!is.na(year)) |>
    filter(year > 1900)

# %%
clean_df
# Out:
#      date       year time       time_of_day   type       country
# 1    2025-11-27 2025 6H 30M 0S  night         unprovoked Australia
# 2    2025-11-27 2025 6H 30M 0S  night         unprovoked Australia
# 7    Evan Campbell                                                   m
# 8    Male child                                                      m
# 9    Samuel Nai                                                      m
# 10   Lee Berryman                                                    m
# 11   Christopher Murray                                              m
# 12   Dr. Mauricio Hoyos                                              m
# 13   Mercury Psillaskis                                              m
# 14   Richard Burrows                                                 m
# 15   Harper Ochoa                                                    f
# 16   Brad Ross                                                       m
# 17   Not stated                                                      m
# 18   Shawn Meuse                                                     m
# 19   Bowie Daley                                                     m
# 20   Eleonora Boi                                                    f
# 21   Nathaniel Drummond                                              m
# 22   Male child                                                      m
# 23   Italian women                                                   f
# 24   Unknown                                                         m
# 25   Jeff Joel                                                       m
# 26   Sam Hollis                                                      m
# 27   Michael Reich                                                   m
# 28   Unknown Male                                                    m
# 29   Unknown Male                                                    m
# 30   Unknown male                                                    m
# ⋮    ⋮                                                               ⋮
# 6265 3 men                                                           m
# 6266 R. Raymond                                                      m
# 6267 William Bartlett                                                m
# 6268 Sydney James                                                    m
# 6269 2 males                                                         m
# 6270 Phil Kitchin                                                    m
# 6271 Frederick Wiseman                                               m
# 6272 Howard Dent                                                     m
# 6273 male                                                            m
# 6274 male                                                            m
# 6275 Row boat; occupants - 2 young men                               m
# 6276 Hawaiian boy                                                    m
# 6277 male                                                            m
# 6278 Harry M. Speerman                                               m
# 6279 Apy                                                             m
# 6280 Giorgos                                                         m
# 6281 Neil Sorenson                                                   m
# 6282 male                                                            m
# 6283 John Ogier                                                      m
# 6284 a soldier from the Natal Garrison                               m
# 6285 Charles Jones                                                   m
# 6286 William Quince                                                  m
# 6287 Dahkus, a Molussa Moro                                          m
# 6288 male                                                            m
# 6289 John Hendrick Adrian Chandler, a prisoner of war                m
# 6290 Antonio Tornatori                                               m
# 6291 boy                                                             m
# 6292 S. McKie, apprentice 1st class on the U.S. Naval ship Annapolis m
# 6293 John Thompson                                                   m
# 6294 Michael O'Brien                                                 m
#      injury
# 1    serious leg injuries
# 2    not stated
# 3    no injury to self
# 4    deep gash to bicep
# 5    injuries to legs
# 6    laceration on top and undermeath right foot
# 7    lacerations to right leg
# 8    severe hand injury
# 9    serious abdonminal injuries
# 10   lacerations to calf
# 11   leg and foot injury
# 12   head face and arms
# 13   both legs and arm severed
# 14   bite to leg
# 15   bite to leg
# 16   none sustained board severly damaged
# 17   severe injuries no detail
# 18   laceration to right leg below the knee
# 19   none sustained board severely damaged
# 20   bite to thigh area
# 21   kayak badly damaged no injury to person
# 22   injuries to right forearm left hand and calf was missing
# 23   gash to leg
# 24   lacerations to left leg above the knee
# 25   lacerations to right forearm
# 26   lacerations to left foot
# 27   lacerations to right arm
# 28   injury to leg
# 29   lacerations to right arm
# 30   mltiple injuries to body
# ⋮    ⋮
# 6265 fatal x 3
# 6266 jumped off cliff
# 6267 fatal
# 6268 fatal
# 6269 fatal
# 6270 fatal, remains (foot) recovered from shark 2 days later
# 6271 fatal
# 6272 fatal
# 6273 severe laceration to hand
# 6274 fatal
# 6275 no injury to occupants, shark grabbed anchor rope & towed boat
# 6276 fatal, both arms severed
# 6277 face & arms injured by hooked shark provoked incident
# 6278 shark bit his left arm after he grabbed its tail provoked incident
# 6279 "nose hanging by a threat, prints of shark's teeth over entire right cheek"
# 6280 bitten on hand and thigh
# 6281 probable drowning & scavenging
# 6282 no injury, hooked shark bit tousers. provoked incident
# 6283 fatal
# 6284 possible drowning & scavenging. remains were recovered from a 15' shark's gut
# 6285 legs bitten
# 6286 lacerations to torso & thigh
# 6287 right thigh bitten
# 6288 fatal, bitten on arms, chest & legs
# 6289 right leg bitten & foot severed, right arm bitten, bones fractured & nearly severed fatal
# 6290 disappeared, but shark involvement unconfirmed
# 6291 NA
# 6292 left thigh stripped of flesh 4" above the knee
# 6293 thigh bitten, fatal
# 6294 abdomen bitten
#      fatal species       size_m size_ft
# 1    0     bull shark    3      NA
# 2    1     bull shark    3      NA
# 3    0     white shark   NA     NA
# 4    0     NA            3      NA
# 5    0     NA            NA     NA
# 6    0     NA            NA     NA
# 7    0     tiger shark   NA     NA
# 8    0     nurse shark   NA     NA
# 9    0     bull shark    NA     NA
# 10   0     bronze whaler NA     NA
# 11   0     NA            1.2    NA
# 12   0     tiger shark   4      NA
# 13   1     white shark   NA     NA
# 14   0     NA            NA     NA
# 15   0     NA            NA     NA
# 16   0     white shark   5      16.5
# 17   0     NA            NA     NA
# 18   0     lemon shark   NA     6
# 19   0     white shark   NA     NA
# 20   0     NA            NA     NA
# 21   0     white shark   3      10
# 22   0     NA            NA     NA
# 23   0     NA            NA     NA
# 24   0     NA            NA     NA
# 25   0     lemon shark   NA     NA
# 26   0     NA            NA     NA
# 27   0     bull shark    1.5    5
# 28   0     NA            NA     NA
# 29   0     NA            NA     NA
# 30   1     NA            NA     NA
# ⋮    ⋮     ⋮             ⋮      ⋮
# 6265 1     NA            NA     NA
# 6266 1     NA            NA     NA
# 6267 1     NA            NA     NA
# 6268 1     bull shark    NA     NA
# 6269 1     NA            NA     NA
# 6270 1     NA            NA     NA
# 6271 1     NA            NA     NA
# 6272 1     NA            NA     NA
# 6273 0     NA            NA     NA
# 6274 1     NA            NA     NA
# 6275 0     NA            NA     NA
# 6276 1     NA            NA     NA
# 6277 0     NA            NA     NA
# 6278 0     NA            NA     NA
# 6279 0     NA            NA     NA
# 6280 0     NA            NA     NA
# 6281 NA    NA            NA     NA
# 6282 0     NA            NA     NA
# 6283 1     NA            NA     NA
# 6284 NA    NA            NA     NA
# 6285 0     NA            NA     NA
# 6286 0     NA            NA     NA
# 6287 0     NA            NA     NA
# 6288 1     NA            NA     NA
# 6289 1     white shark   NA     NA
# 6290 NA    NA            NA     NA
# 6291 NA    NA            NA     NA
# 6292 0     NA            NA     NA
# 6293 1     NA            NA     NA
# 6294 0     NA            NA     NA
